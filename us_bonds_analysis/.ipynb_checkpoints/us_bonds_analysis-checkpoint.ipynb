# %%
import pandas as pd
import numpy as np

df = pd.read_excel('iShares-iBoxx--Investment-Grade-Corporate-Bond-ETF_fund.xls', skiprows=7)
df.head()
# Out:
#                                  Name                   Sector   Asset Class  \
# 0      BLK CSH FND TREASURY SL AGENCY  Cash and/or Derivatives  Money Market
# 1        ANHEUSER-BUSCH COMPANIES LLC    Consumer Non-Cyclical  Fixed Income
# 2  GE CAPITAL INTERNATIONAL FUNDING C        Finance Companies  Fixed Income
# 3                     CVS HEALTH CORP    Consumer Non-Cyclical  Fixed Income
# 4                     CVS HEALTH CORP    Consumer Non-Cyclical  Fixed Income
#
#    Market Value  Weight (%)  Notional Value  Par Value      CUSIP  \
# 0  6.347540e+08     1.09734    6.347540e+08  634754000  066922477
# 1  1.780641e+08     0.30783    1.780641e+08  136538000  03522AAJ9
# 2  1.729579e+08     0.29900    1.729579e+08  164076000  36164QNA2
# 3  1.709580e+08     0.29554    1.709580e+08  120791000  126650CZ1
# 4  1.603515e+08     0.27721    1.603515e+08  132929000  126650CX6
#
#            ISIN    SEDOL  ...  YTM (%) FX Rate      Maturity Coupon (%)  \
# 0  US0669224778       --  ...     0.10       1            --       0.16
# 1  US03522AAJ97  BJXS2M9  ...     3.16       1  Feb 01, 2046       4.90
# 2  US36164QNA21  BYNWXZ6  ...     4.03       1  Nov 15, 2035       4.42
# 3  US126650CZ11  BF4JKH4  ...     2.94       1  Mar 25, 2048       5.05
# 4  US126650CX62  BF3V2P3  ...     1.64       1  Mar 25, 2028       4.30
#
#    Mod. Duration  Yield to Call (%)  Yield to Worst (%) Real Duration  \
# 0           0.13                 --                0.10          0.13
# 1          15.94                 --                3.14         15.76
# 2          11.04                 --                4.03         11.04
# 3          16.68                 --                2.92         16.51
# 4           6.55                 --                1.56          6.36
#
#    Real YTM (%)  Market Currency
# 0          0.10              USD
# 1          3.14              USD
# 2          4.03              USD
# 3          2.92              USD
# 4          1.56              USD
#
# [5 rows x 25 columns]

# %%
df['Maturity'] = pd.to_datetime(df['Maturity'], format='%b %d, %Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/learnCoding/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-418dc191b810> in <module>
# ----> 1 df['Maturity'] = pd.to_datetime(df['Maturity'], format='%b/%d/%Y')
#
# ~/miniconda3/envs/learnCoding/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/miniconda3/envs/learnCoding/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     434             except (ValueError, TypeError):
# --> 435                 raise e
#     436
#     437     if result is None:
#
# ~/miniconda3/envs/learnCoding/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     397             if result is None:
#     398                 try:
# --> 399                     result, timezones = array_strptime(
#     400                         arg, format, exact=exact, errors=errors
#     401                     )
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '--' does not match format '%b/%d/%Y' (match)
